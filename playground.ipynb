# %% [markdown]
# # SoundCloud Matching Accuracy Test
#
# Test the accuracy of matching SoundCloud tracks to local tracks using metadata similarity.
#
# **Goal**: Verify ~170/200 tracks match correctly before implementing incremental sync.

# %% [markdown]
# ## 1. Setup & Imports

# %%
import sys

sys.path.insert(0, "/home/kevin/coding/music-minion-cli/src")

from music_minion.domain.library.providers import soundcloud
from music_minion.domain.library.provider import ProviderConfig
from music_minion.domain.library.deduplication import (
    normalize_string,
    find_best_matches_tfidf,
    apply_manual_corrections,
)
from music_minion.core import database

import pandas as pd
import time
from typing import List, Dict, Any, Tuple

# %% [markdown]
# ## 2. Fetch SoundCloud Tracks (First 200)

# %%
# Initialize SoundCloud provider
config = ProviderConfig(name="soundcloud", enabled=True)
state = soundcloud.init_provider(config)

print(f"Authenticated: {state.authenticated}")

if not state.authenticated:
    print("\n⚠️  Token expired or not authenticated")
    print("Re-authenticating...")

    # Try to get token from database and refresh if expired
    db_state = database.load_provider_state("soundcloud")

    if db_state and db_state.get("auth_data"):
        auth_data = db_state["auth_data"]

        # Try to refresh token
        new_token_data = soundcloud._refresh_token(auth_data)

        if new_token_data:
            print("✓ Token refreshed successfully!")

            # Save to database
            config_data = db_state.get("config_data", {})
            database.save_provider_state("soundcloud", new_token_data, config_data)

            # Reinitialize with new token
            state = soundcloud.init_provider(config)
            print(f"✓ Re-authenticated: {state.authenticated}")
        else:
            raise Exception("Token refresh failed. Run in CLI: library auth soundcloud")
    else:
        raise Exception(
            "Not authenticated with SoundCloud. Run in CLI: library auth soundcloud"
        )
# Out:
# Authenticated: True

# %%
token_data = state.cache.get("token_data")
access_token = token_data["access_token"]

# Single API request for first page
import requests

url = "https://api.soundcloud.com/me/playlists"
headers = {"Authorization": f"OAuth {access_token}"}
params = {
    "limit": 200,
    "linked_partitioning": True,
}

response = requests.get(url, params=params, headers=headers, timeout=30)
response.raise_for_status()
data = response.json()

# %%
df = pd.json_normalize(data["collection"])

# %%
df.iloc[10].to_dict()
# Out:
# {'duration': 7238869,
#  'genre': '',
#  'release_day': None,
#  'permalink': 'jul-25',
#  'permalink_url': 'https://soundcloud.com/kevinbigfoot/sets/jul-25?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#  'release_month': None,
#  'release_year': None,
#  'description': '',
#  'uri': 'https://api.soundcloud.com/playlists/soundcloud:playlists:2047400703',
#  'label_name': None,
#  'label_id': None,
#  'label': None,
#  'tag_list': '',
#  'track_count': 41,
#  'user_id': 15999805,
#  'user_urn': 'soundcloud:users:15999805',
#  'last_modified': '2025/07/30 01:00:13 +0000',
#  'license': 'all-rights-reserved',
#  'playlist_type': 'PLAYLIST',
#  'type': 'PLAYLIST',
#  'id': 2047400703,
#  'urn': 'soundcloud:playlists:2047400703',
#  'downloadable': None,
#  'likes_count': 0,
#  'repost_count': 0,
#  'sharing': 'public',
#  'created_at': '2025/07/06 19:44:04 +0000',
#  'release': None,
#  'tags': '',
#  'kind': 'playlist',
#  'title': 'Jul 25',
#  'purchase_title': None,
#  'ean': None,
#  'streamable': True,
#  'embeddable_by': 'all',
#  'artwork_url': None,
#  'purchase_url': None,
#  'tracks_uri': 'https://api.soundcloud.com/playlists/soundcloud:playlists:2047400703/tracks',
#  'secret_token': nan,
#  'secret_uri': nan,
#  'tracks': [{'kind': 'track',
#    'id': 2120946690,
#    'urn': 'soundcloud:tracks:2120946690',
#    'created_at': '2025/06/28 03:54:34 +0000',
#    'duration': 171468,
#    'commentable': True,
#    'comment_count': 60,
#    'sharing': 'public',
#    'tag_list': ' Dubstep',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': None,
#    'purchase_title': None,
#    'genre': 'Electronic',
#    'title': 'The Device',
#    'description': None,
#    'label_name': 'Ransom Records',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'QZWV32524713',
#    'bpm': None,
#    'release_year': 2025,
#    'release_month': 7,
#    'release_day': 10,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2120946690',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-E3LGKpNbJgd1BaRS-qk8Y1g-large.jpg',
#     'id': 983889628,
#     'urn': 'soundcloud:users:983889628',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/the-hostage-situation?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:983889628',
#     'username': 'Hostage Situation',
#     'permalink': 'the-hostage-situation',
#     'created_at': '2021/05/11 20:24:51 +0000',
#     'last_modified': '2025/11/06 19:34:37 +0000',
#     'first_name': 'Hostage',
#     'last_name': 'Situation',
#     'full_name': 'Hostage Situation',
#     'city': 'Denver',
#     'description': "Are you kickin' it?",
#     'country': None,
#     'track_count': 105,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 20814,
#     'followings_count': 131,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'Apple Music',
#     'website': 'https://music.apple.com/us/artist/hostage-situation/1587213527',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 20,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/the-hostage-situation/the-device?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-gw4XSmv3ihdM-0-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2120946690/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/MUIefQ7VQwc8_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 39913,
#    'download_count': 0,
#    'favoritings_count': 2477,
#    'reposts_count': 90,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'Hostage Situation'},
#   {'kind': 'track',
#    'id': 2119019871,
#    'urn': 'soundcloud:tracks:2119019871',
#    'created_at': '2025/06/25 00:08:14 +0000',
#    'duration': 138031,
#    'commentable': True,
#    'comment_count': 301,
#    'sharing': 'public',
#    'tag_list': ' ',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://hypeddit.com/spritzur/fredagainxskeptavictorylapspritzurremix',
#    'purchase_title': 'Free Download',
#    'genre': '',
#    'title': 'Fred again.. x Skepta - Victory Lap (Spritzur Remix)',
#    'description': '',
#    'label_name': '',
#    'release': None,
#    'key_signature': None,
#    'isrc': None,
#    'bpm': None,
#    'release_year': None,
#    'release_month': None,
#    'release_day': None,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2119019871',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-4wr8vHH0lxFoOLhy-0cJyBA-large.jpg',
#     'id': 565256499,
#     'urn': 'soundcloud:users:565256499',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/spritzurofficial?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:565256499',
#     'username': 'Spritzur',
#     'permalink': 'spritzurofficial',
#     'created_at': '2019/01/01 23:00:00 +0000',
#     'last_modified': '2025/11/10 00:46:11 +0000',
#     'first_name': '',
#     'last_name': '',
#     'full_name': '',
#     'city': 'Alberta',
#     'description': 'Subcarbon | Tribal Trap | EMENGY \n\nPromo: spritzur31@gmail.com',
#     'country': 'Canada',
#     'track_count': 10,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 481206,
#     'followings_count': 141,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': None,
#     'website': None,
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 24,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/spritzurofficial/fred-again-x-skepta-victory?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-O8kV7Flfl0SVXX9A-qbXCGw-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2119019871/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/dG9vK7LXaxNX_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 21157,
#    'download_count': 0,
#    'favoritings_count': 1276,
#    'reposts_count': 343,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': None},
#   {'kind': 'track',
#    'id': 2116477500,
#    'urn': 'soundcloud:tracks:2116477500',
#    'created_at': '2025/06/20 02:07:15 +0000',
#    'duration': 124317,
#    'commentable': True,
#    'comment_count': 396,
#    'sharing': 'public',
#    'tag_list': ' Electronic Grime Dubstep trap fredagain skepta plaqueboymax 140',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://hypeddit.com/fredagainskeptaplaqueboymax/victorylaphgodsremix-1',
#    'purchase_title': 'Free Download',
#    'genre': 'Dubstep',
#    'title': 'Fred Again.., Skepta, PlaqueBoyMax - Victory Lap (HGods Remix)',
#    'description': 'FREE DOWNLOAD !\n\nSOCIALS / MERCH / STREAMING\n\nSPOTIFY: https://open.spotify.com/artist/1mrXo5fhYhx3gEiLjbOtYA?si=k3-yzA_TRfqDabjxvVGflg\nMERCH: https://www.thickasthievesbk.com/collections/collaborations\nwww.instagram.com/hgods_official/\ntwitter.com/HGodsOfficial\nwww.facebook.com/HGodsOfficial\n\n#bassmusic #dubstep #edm #remix',
#    'label_name': '',
#    'release': None,
#    'key_signature': None,
#    'isrc': None,
#    'bpm': None,
#    'release_year': 2025,
#    'release_month': 6,
#    'release_day': 20,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2116477500',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-9099g4dz6sTbRITX-B9YjeA-large.jpg',
#     'id': 66171368,
#     'urn': 'soundcloud:users:66171368',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/hgods?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:66171368',
#     'username': 'HGods',
#     'permalink': 'hgods',
#     'created_at': '2013/11/12 20:34:49 +0000',
#     'last_modified': '2025/08/11 15:30:24 +0000',
#     'first_name': 'Hunter',
#     'last_name': 'Godsey',
#     'full_name': 'Hunter Godsey',
#     'city': 'Brooklyn, NY',
#     'description': 'Award losing producer\n\nhttps://linktr.ee/hgods\n\nFollow me on Spotify! https://open.spotify.com/artist/1mrXo5fhYhx3gEiLjbOtYA?si=VkgnkzZDRSyizUPV8MBXww\n\nMGMT: Chad@audisbliss.com',
#     'country': 'United States',
#     'track_count': 66,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 8511,
#     'followings_count': 562,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'Twitch',
#     'website': 'https://www.twitch.tv/hgods_official',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 3,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/hgods/fred-again-victory-lap-hgods?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-XddVBMDkmeyAyppi-zHXkuw-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2116477500/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/D5HPOKOFygQ0_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 34537,
#    'download_count': 4,
#    'favoritings_count': 1722,
#    'reposts_count': 370,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'HGods'},
#   {'kind': 'track',
#    'id': 2122146849,
#    'urn': 'soundcloud:tracks:2122146849',
#    'created_at': '2025/06/30 16:51:13 +0000',
#    'duration': 99474,
#    'commentable': True,
#    'comment_count': 18,
#    'sharing': 'public',
#    'tag_list': ' "Dance & EDM" "Hip-hop & Rap"',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': None,
#    'purchase_title': None,
#    'genre': 'Dubstep',
#    'title': 'Skrillex - Spitfire ft. hawaii slim [ Noize Complaint Remix ]',
#    'description': 'WHO GONNA PLAY IT OUT AND SEND ME A VIDEO FIRST???\n\nFREE DOWNLOAD --> https://hypeddit.com/noizecomplaint/spitfireremix\n\n-- www.noizecomplaint.com --',
#    'label_name': '',
#    'release': None,
#    'key_signature': None,
#    'isrc': None,
#    'bpm': None,
#    'release_year': None,
#    'release_month': None,
#    'release_day': None,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2122146849',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-IDy2DJyPayDqz5CC-rH8RFw-large.jpg',
#     'id': 1348969956,
#     'urn': 'soundcloud:users:1348969956',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/noizecomplaintlive?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:1348969956',
#     'username': 'Noize Complaint',
#     'permalink': 'noizecomplaintlive',
#     'created_at': '2024/01/18 18:43:25 +0000',
#     'last_modified': '2025/11/12 21:21:43 +0000',
#     'first_name': 'Jake',
#     'last_name': '',
#     'full_name': 'Jake',
#     'city': 'NYC',
#     'description': 'Extra noisy music from NYC. \nDL serum presets from my remixes below.\n\nall inquiries: mgmt@noizecomplaint.com',
#     'country': None,
#     'track_count': 18,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 38774,
#     'followings_count': 414,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'NOIZECOMPLAINT.COM',
#     'website': 'http://noizecomplaint.com',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 3,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/noizecomplaintlive/spitfireremix?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-jzSTSyL3i85nMWEo-6IPR9A-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2122146849/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/Hnewyzgd7eAM_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 7103,
#    'download_count': 0,
#    'favoritings_count': 414,
#    'reposts_count': 90,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'Noize Complaint'},
#   {'kind': 'track',
#    'id': 2118036966,
#    'urn': 'soundcloud:tracks:2118036966',
#    'created_at': '2025/06/23 12:48:44 +0000',
#    'duration': 198478,
#    'commentable': True,
#    'comment_count': 246,
#    'sharing': 'public',
#    'tag_list': ' 150bpm dubstep trap "bass music" electronic',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'http://hypeddit.com/starseed/metaphysical',
#    'purchase_title': 'Stream/Download',
#    'genre': 'Dubstep',
#    'title': 'STAR SEED - Metaphysical',
#    'description': "Let's get metaphysical ☾₊‧⁺˖⋆ Stream/Download: https://hypeddit.com/starseed/metaphysical",
#    'label_name': '',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'QM8DG2577817',
#    'bpm': None,
#    'release_year': None,
#    'release_month': None,
#    'release_day': None,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2118036966',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-tePRgkRtsozpyQIo-q12nxg-large.jpg',
#     'id': 1832273,
#     'urn': 'soundcloud:users:1832273',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/starseedsound?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:1832273',
#     'username': 'STAR SEED',
#     'permalink': 'starseedsound',
#     'created_at': '2010/10/03 19:27:50 +0000',
#     'last_modified': '2025/10/17 19:17:11 +0000',
#     'first_name': '',
#     'last_name': '',
#     'full_name': '',
#     'city': '',
#     'description': 'Stardust into soundwaves ✨🍃\n\nmgmt:\npeter@ambushartists.com',
#     'country': None,
#     'track_count': 72,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 45854,
#     'followings_count': 1,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'Merch',
#     'website': 'https://www.starseedsound.com/merch',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 28,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/starseedsound/metaphysical?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-Ghlg9i6vwMYo7N3O-W5QjGg-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2118036966/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/bvpwfDCtxs3e_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 17422,
#    'download_count': 0,
#    'favoritings_count': 1165,
#    'reposts_count': 233,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'STAR SEED'},
#   {'kind': 'track',
#    'id': 2129881437,
#    'urn': 'soundcloud:tracks:2129881437',
#    'created_at': '2025/07/14 19:57:19 +0000',
#    'duration': 176039,
#    'commentable': True,
#    'comment_count': 12,
#    'sharing': 'public',
#    'tag_list': ' Subsidia "Edison Cole" Linney Vertigo',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://subsidia.lnk.to/vertigo',
#    'purchase_title': 'SUPPORT/STREAM',
#    'genre': 'Dubstep',
#    'title': 'Edison Cole & Linney - Vertigo',
#    'description': 'Edison Cole & Linney - Vertigo | Out Now On Subsidia\nSUPPORT/STREAM HERE:\nhttps://subsidia.lnk.to/vertigo\n\n@SUBSIDIA  \nhttps://www.facebook.com/SubsidiaRecords\nhttps://twitter.com/SubsidiaRecords\nhttps://www.instagram.com/SubsidiaRecords\nhttps://www.youtube.com/c/SUBSIDIA?sub_confirmation=1\nhttps://subsidia.ca\n\nEDISON COLE:\nhttps://www.facebook.com/ItsEdisonCole\nhttps://www.instagram.com/itsedisoncole\nhttps://x.com/itsedisoncole\n\nLINNEY\nhttps://www.facebook.com/linneyofficial\nhttps://twitter.com/linneyofficial\nhttps://www.instagram.com/linney\n\nVisit https://subsidia.ca for more music, merch, and updates!\n#Subsidia #EdisonCole #Linney',
#    'label_name': 'Subsidia',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'QZHCR2500039',
#    'bpm': None,
#    'release_year': 2025,
#    'release_month': 7,
#    'release_day': 16,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2129881437',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-SyaBXC7wudb3WnN9-xFvOzA-large.jpg',
#     'id': 878808553,
#     'urn': 'soundcloud:users:878808553',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/subsidia?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:878808553',
#     'username': 'Subsidia',
#     'permalink': 'subsidia',
#     'created_at': '2020/09/09 00:45:49 +0000',
#     'last_modified': '2025/11/14 17:16:16 +0000',
#     'first_name': '',
#     'last_name': '',
#     'full_name': '',
#     'city': None,
#     'description': 'You have arrived. Welcome to Excision’s record label: Subsidia.\n\nGet ready to be immersed in a musical landscape that will evolve with you throughout each day.',
#     'country': None,
#     'track_count': 781,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 2401,
#     'followings_count': 132,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'Subsidia Website',
#     'website': 'https://subsidia.ca',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 84,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/subsidia/edison-cole-linney-vertigo?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-7DN5iaOnR72LEd7z-JX2iuA-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2129881437/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/F8GwCpI5wZUI_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 15507,
#    'download_count': 0,
#    'favoritings_count': 733,
#    'reposts_count': 52,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'Edison Cole,  Linney'},
#   {'kind': 'track',
#    'id': 2132441535,
#    'urn': 'soundcloud:tracks:2132441535',
#    'created_at': '2025/07/18 15:38:18 +0000',
#    'duration': 248764,
#    'commentable': True,
#    'comment_count': 44,
#    'sharing': 'public',
#    'tag_list': ' "Dance & EDM" Dubstep',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': None,
#    'purchase_title': None,
#    'genre': 'Dance & EDM',
#    'title': 'Take Me to My Grave',
#    'description': "Stream Seven Lions, Quackson & Grabbitz - Take Me To My Grave: https://ffm.to/tmtmg \nFollow the 'Ophelia New Releases' Spotify playlist: https://ophelia.ffm.to/newreleases\nFollow the ‘Ophelia Melodic’ Spotify playlist: https://ophelia.ffm.to/melodic  \n\nSeven Lions, Quackson & Grabbitz - Take Me To My Grave [Official Audio] | Ophelia Records\n\nSeven Lions\nInstagram: https://www.instagram.com/sevenlions\nFacebook: https://www.facebook.com/sevenlions\nX: https://www.x.com/sevenlionsmusic\n\nQuackson\nInstagram: https://www.instagram.com/quacksonmusic\nFacebook: https://www.facebook.com/quacksonmusic\nTwitter: https://www.twitter.com/quacksonmusic\n\nOphelia Records\nOphelia Records Official Facebook: https://www.facebook.com/OpheliaRecords\nOphelia Records Official Instagram: https://www.instagram.com/ophelia_records\nOphelia Records Official Twitter: https://twitter.com/OpheliaRecords\nOphelia Records Official Soundcloud: https://soundcloud.com/ophelia_records\nOphelia Records Official Website: https://opheliarecords.com/\n\nAs the official record label of melodic dubstep leader Seven Lions, Ophelia Records is a label that promotes independent dance music across a wide range of genres. In just five years, Ophelia has become one of the hottest labels in electronic music thanks to its tight-knit community and ability to connect fans of melodic bass, dubstep, trance, psytrance, drum & bass, house and beyond. Releases have picked up support on flagship playlists across DSPs and radio stations, including the cover of Spotify’s Mint, SiriusXM BPM playlisting and numerous adds to New Music Friday, Dance Rising, danceXL, Bass Arcade and more. With massive releases from acts such as SLANDER, Excision, Kill The Noise, MitiS, Jason Ross, NGHTMRE, Wooli, Trivecta, Blastoyz, Crystal Skies and Last Heroes, Ophelia has reached significant milestones with over 200 catalog releases, multiple #1 iTunes Dance records, sold out showcases and festival takeovers.",
#    'label_name': '',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'CA5KR2539431',
#    'bpm': None,
#    'release_year': None,
#    'release_month': None,
#    'release_day': None,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2132441535',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-vc9s9OdCC79PcHTB-SvQQtw-large.jpg',
#     'id': 659761,
#     'urn': 'soundcloud:users:659761',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/seven-lions?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:659761',
#     'username': 'Seven Lions',
#     'permalink': 'seven-lions',
#     'created_at': '2010/02/24 18:36:48 +0000',
#     'last_modified': '2025/11/12 16:59:16 +0000',
#     'first_name': 'Jeff',
#     'last_name': 'Montalvo',
#     'full_name': 'Jeff Montalvo',
#     'city': '',
#     'description': 'Management: \nPaulette Varelas - paulette@mlennial.com\nMike Lisanti - ml@mlennial.com\n\nBookings:\nMatthew Rodriguez - mrodriguez@teamwass.com',
#     'country': None,
#     'track_count': 356,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 2975,
#     'followings_count': 564,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'Ophelia Records',
#     'website': 'https://opheliarecords.com/',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 71,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/seven-lions/take-me-to-my-grave?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-bnUr6XZYUESP4ivb-iXIcyg-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2132441535/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/ENUoYQdQgPqO_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 39250,
#    'download_count': 0,
#    'favoritings_count': 2039,
#    'reposts_count': 119,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'Seven Lions, Quackson, Grabbitz'},
#   {'kind': 'track',
#    'id': 2120936580,
#    'urn': 'soundcloud:tracks:2120936580',
#    'created_at': '2025/06/28 03:10:39 +0000',
#    'duration': 137169,
#    'commentable': True,
#    'comment_count': 478,
#    'sharing': 'public',
#    'tag_list': ' ',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://hypeddit.com/prettysweet/mikesway',
#    'purchase_title': 'Free Download',
#    'genre': 'Dubstep',
#    'title': "Mike's Way",
#    'description': "Pretty Sweet is comprised of two dudes. One of them is named Mike, and I'm sure you can guess how he likes his sub.\n\nFree DL : https://hypeddit.com/prettysweet/mikesway\n\nSUPPORT: @prettysweet2\nInstagram: www.instagram.com/whoisprettysweet/\nSpotify: https://open.spotify.com/artist/1tGxccjxxG3IlNwSs2x8eX?si=d8ayYuv0Q6epypdsAEQyeA\nTikTok: @whoisprettysweet\nx: x.com/PrettyFnSweet",
#    'label_name': '',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'QZTGW2405925',
#    'bpm': None,
#    'release_year': None,
#    'release_month': None,
#    'release_day': None,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2120936580',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-kCQ4fjiyzUgLObrB-I19lDw-large.jpg',
#     'id': 344447819,
#     'urn': 'soundcloud:users:344447819',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/prettysweet2?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:344447819',
#     'username': 'Pretty Sweet',
#     'permalink': 'prettysweet2',
#     'created_at': '2017/11/07 04:19:04 +0000',
#     'last_modified': '2025/11/05 04:50:09 +0000',
#     'first_name': '',
#     'last_name': '',
#     'full_name': '',
#     'city': '',
#     'description': "We make festival music, it's Pretty Sweet.\n\nBookings: blachman@corsonagency.com\nManagement: rj@offcentermgmt.com \n\n\nContact:\nPrettysweetofficial@gmail.com\n\nSupport :\n@Wubaholics\n@DiscoveryProject\n@Rudeservice\n@Digitalvibrationshq\n@thedubrebellion\n@Emengy\n@Tribaltrapmusic\n@Basscvlt\n@Wicked_Records",
#     'country': 'United States',
#     'track_count': 31,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 657,
#     'followings_count': 404,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'Patreon',
#     'website': 'http://patreon.com/WhoIsPrettySweet',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 16,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/prettysweet2/mikes-way?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-jOME0Xlh8zfNCHRV-e3rIiA-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2120936580/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/G7lmvHKCZrpR_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 70521,
#    'download_count': 2,
#    'favoritings_count': 4860,
#    'reposts_count': 466,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'Pretty Sweet'},
#   {'kind': 'track',
#    'id': 2128056261,
#    'urn': 'soundcloud:tracks:2128056261',
#    'created_at': '2025/07/10 22:40:07 +0000',
#    'duration': 144039,
#    'commentable': True,
#    'comment_count': 124,
#    'sharing': 'public',
#    'tag_list': ' Dubstep EDM Heavy Headbanger Mashup Edit Flip LMFAO Wooli Excision ONARA ROI Riddim 145 PartyRockAnthem SorryForPartyRocking "Name Drop" BERZERK RoiTheDigger RiddimHours MoshPit 2025 New Music Tearout Throwback',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://hypeddit.com/lmfaowooliexcisiononararoi/partyrockanthemelusidmashup',
#    'purchase_title': 'Free Download',
#    'genre': 'Dubstep',
#    'title': 'LMFAO, Excision, Wooli, ONARA, Roi* - Party Rock Anthem (ELUSID Mashup)',
#    'description': 'lmk what you think in the comments :))\n--\nTRACK ID:\nLMFAO - Party Rock Anthem\nExcision, Wooli - Name Drop\nONARA - BERZERK\nROI* - roi the digger [2nd drop fills]',
#    'label_name': '',
#    'release': None,
#    'key_signature': None,
#    'isrc': None,
#    'bpm': None,
#    'release_year': None,
#    'release_month': None,
#    'release_day': None,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2128056261',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-pwD12NlEvNcUIwzD-6sbiHw-large.jpg',
#     'id': 478696548,
#     'urn': 'soundcloud:users:478696548',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/elusidmusic?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:478696548',
#     'username': 'ELUSID',
#     'permalink': 'elusidmusic',
#     'created_at': '2018/07/15 22:27:04 +0000',
#     'last_modified': '2025/11/17 22:03:26 +0000',
#     'first_name': '',
#     'last_name': '',
#     'full_name': '',
#     'city': 'Toronto',
#     'description': 'every monday, all year\nMelodic Bass / Dubstep / Riddim\n[ALL FREE DL]',
#     'country': 'Canada',
#     'track_count': 119,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 3977,
#     'followings_count': 154,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'Apple Music',
#     'website': 'https://music.apple.com/us/artist/elusid/1592587653',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 8,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/elusidmusic/party-rock-elusid-mashup?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-BAZWi0A4Mt8FwyTE-J2kzWA-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2128056261/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/zvv8aLrLY56o_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 11880,
#    'download_count': 0,
#    'favoritings_count': 657,
#    'reposts_count': 111,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'ELUSID'},
#   {'kind': 'track',
#    'id': 2076072384,
#    'urn': 'soundcloud:tracks:2076072384',
#    'created_at': '2025/04/11 06:55:28 +0000',
#    'duration': 206942,
#    'commentable': True,
#    'comment_count': 492,
#    'sharing': 'public',
#    'tag_list': ' Dubstep DRUMSTEP "Drum & Bass" EXCISION',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://hypeddit.com/viideadkymojaydinsee/makeitbang',
#    'purchase_title': 'FREE DOWNLOAD',
#    'genre': 'Drum & Bass',
#    'title': 'VII DEAD & KyMo & JAYDINSEE - MAKE IT BANG',
#    'description': 'MAKE IT BANG // FINALLY OUT NOW!!! \n\n***SUPPORTED BY 𝐄𝐗𝐂𝐈𝐒𝐈𝐎𝐍 at Thunderdome, EDC MEXICO, AND MORE\n\nThe 3 of us are so unbelievably honored at the great response and support of this song!!! \nIt was our first time doing dnb, and we couldn’t be happier with the end result. We hope to run this trio back again soon!!!\n\nVII DEAD:\nhttps://soundcloud.com/viidead\nhttps://www.instagram.com/viidead/\n\nKYMO: \nhttps://soundcloud.com/kymomusic\nhttps://www.instagram.com/kymo_official/\n\nJAYDINSEE:\nhttps://soundcloud.com/jaydinsee\nhttps://www.instagram.com/jaydinsee/',
#    'label_name': '',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'QM8DG2536167',
#    'bpm': None,
#    'release_year': 2025,
#    'release_month': 4,
#    'release_day': 7,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2076072384',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-Xu9DzgcP9XJlyE2z-RB9Jvg-large.jpg',
#     'id': 530797020,
#     'urn': 'soundcloud:users:530797020',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/viidead?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:530797020',
#     'username': 'VII DEAD',
#     'permalink': 'viidead',
#     'created_at': '2018/10/28 02:04:52 +0000',
#     'last_modified': '2025/09/30 01:08:03 +0000',
#     'first_name': '',
#     'last_name': '',
#     'full_name': '',
#     'city': 'Portland, OR',
#     'description': 'BOOKING: ZeroDigitsMGMT@gmail.com\n\nVII DEAD (Seven Dead) brings a mix of \nhigh-energy bass music to the scene.\nFrom dubstep, drum & bass, techno, and more... he’s got you covered.\nFrom his ethereal sounds and storytelling to his fun melodies, he tells a story of redemption through music — that with passion and purpose,\nyou can overcome anything, even death.\n\n𝖄𝖔𝖚 𝖍𝖆𝖛𝖊 𝖙𝖔 𝖉𝖎𝖊 𝖙𝖔 𝖑𝖎𝖛𝖊...',
#     'country': 'United States',
#     'track_count': 15,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 22200,
#     'followings_count': 80,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'Tiktok',
#     'website': 'https://www.tiktok.com/@viideadmusic?lang=en',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 5,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/viidead/vii-dead-kymo-jaydinsee-make-it-bang?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-EzwZHIgvU6ZFiEyz-eGDlxg-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2076072384/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/Nmqcv5nLlPSj_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 16019,
#    'download_count': 19,
#    'favoritings_count': 1362,
#    'reposts_count': 131,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'VII DEAD, KyMo, JAYDINSEE'},
#   {'kind': 'track',
#    'id': 2131355784,
#    'urn': 'soundcloud:tracks:2131355784',
#    'created_at': '2025/07/16 23:11:21 +0000',
#    'duration': 192705,
#    'commentable': True,
#    'comment_count': 327,
#    'sharing': 'public',
#    'tag_list': ' "Uk " Dubstep Trap',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://hypeddit.com/gawmmusiccc/victorylapgawmflip',
#    'purchase_title': 'Free Download',
#    'genre': 'Trap',
#    'title': 'Victory Lap (GAWM FLIP)',
#    'description': '',
#    'label_name': '',
#    'release': None,
#    'key_signature': None,
#    'isrc': None,
#    'bpm': None,
#    'release_year': None,
#    'release_month': None,
#    'release_day': None,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2131355784',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-Xnlt9N7jhXDKIpij-XIak8w-large.jpg',
#     'id': 657173,
#     'urn': 'soundcloud:users:657173',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/gawmmusic?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:657173',
#     'username': 'GAWM',
#     'permalink': 'gawmmusic',
#     'created_at': '2010/02/24 06:14:52 +0000',
#     'last_modified': '2025/11/14 07:22:27 +0000',
#     'first_name': 'Kris',
#     'last_name': 'Rod',
#     'full_name': 'Kris Rod',
#     'city': 'LOS ANGELES ',
#     'description': '(Pronounced GOM not GUAM)\n\nText me 1+323-831-0309 \n\nUS BOOKING - gawmmusic@gmail.com\n\nLabel : https://soundcloud.com/murder-we-wrote',
#     'country': None,
#     'track_count': 81,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 2638,
#     'followings_count': 457,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'GAWM Website',
#     'website': 'https://gawm.bandzoogle.com/home',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 49,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/gawmmusic/3d4f9c3f-9d40-4a2e-b139-92ffd0c0d146?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-zZoGMRCbte1fLGbe-V9XvtA-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2131355784/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/UhsJDwPeeCdL_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 18663,
#    'download_count': 0,
#    'favoritings_count': 1381,
#    'reposts_count': 449,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'Fred Again'},
#   {'kind': 'track',
#    'id': 2122924254,
#    'urn': 'soundcloud:tracks:2122924254',
#    'created_at': '2025/07/01 23:26:09 +0000',
#    'duration': 114887,
#    'commentable': True,
#    'comment_count': 7,
#    'sharing': 'public',
#    'tag_list': ' ',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://outnow.io/t/myrias-underworld',
#    'purchase_title': 'Stream/Download',
#    'genre': '',
#    'title': 'MYRIAS - UNSEEN',
#    'description': 'OUT NOW - https://outnow.io/t/myrias-underworld\n\nFollow @myriasmusic\n\nhttps://linktr.ee/myriasmusic\n\nFollow @subcarbon\n\nhttps://www.subcarbon.be\nhttps://facebook.com/Subcarbon\nhttps://www.youtube.com/user/SubcarbonRecords\nhttps://twitter.com/subcarbon\nhttps://www.instagram.com/subcarbon\nSubmissions: submissions@subcarbon.be\nSpotify playlist: https://tiny.cc/scspotify',
#    'label_name': 'Subcarbon Records',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'TCAJU2527270',
#    'bpm': None,
#    'release_year': None,
#    'release_month': None,
#    'release_day': None,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2122924254',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-qt6RwVhgoU4yq0V3-vDAeXQ-large.jpg',
#     'id': 81724548,
#     'urn': 'soundcloud:users:81724548',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/subcarbon?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:81724548',
#     'username': 'SubCarbon Records',
#     'permalink': 'subcarbon',
#     'created_at': '2014/02/24 13:23:39 +0000',
#     'last_modified': '2025/11/14 17:54:29 +0000',
#     'first_name': 'Subcarbon',
#     'last_name': 'Records',
#     'full_name': 'Subcarbon Records',
#     'city': 'Los Angeles',
#     'description': 'Music Label created by Ganja White Night in 2009.\n\nWe do not answer Soundcloud messages, submit your songs by email : submissions@subcarbon.be\n\nGeneral inquiries : team.subcarbon@gmail.com',
#     'country': 'United States',
#     'track_count': 588,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 4694,
#     'followings_count': 1834,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': None,
#     'website': None,
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 86,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/subcarbon/myrias-unseen?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-2wOoHll8Da0HPTb2-XIZ3xQ-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2122924254/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/cclduby9sdJ6_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 6849,
#    'download_count': 0,
#    'favoritings_count': 273,
#    'reposts_count': 24,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'MYRIAS'},
#   {'kind': 'track',
#    'id': 2119828623,
#    'urn': 'soundcloud:tracks:2119828623',
#    'created_at': '2025/06/26 11:55:27 +0000',
#    'duration': 174785,
#    'commentable': True,
#    'comment_count': 224,
#    'sharing': 'public',
#    'tag_list': ' Dubstep',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': None,
#    'purchase_title': None,
#    'genre': 'Electronic',
#    'title': 'Coast 2 Coast ft. Flowdan',
#    'description': None,
#    'label_name': 'GRiZ LLC',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'QZWV32527632',
#    'bpm': None,
#    'release_year': 2025,
#    'release_month': 7,
#    'release_day': 18,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2119828623',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-LlgzQI5Rtvfr6Cnl-Lr4Iyg-large.jpg',
#     'id': 110021,
#     'urn': 'soundcloud:users:110021',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/griz?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:110021',
#     'username': 'GRiZ',
#     'permalink': 'griz',
#     'created_at': '2009/04/30 08:08:55 +0000',
#     'last_modified': '2025/11/14 23:18:51 +0000',
#     'first_name': 'MAD☩LiBERATOR',
#     'last_name': '',
#     'full_name': 'MAD☩LiBERATOR',
#     'city': 'Detroit',
#     'description': 'Find me on Insta / Twitter / Facebook and say whattup!\n#ShowLoveSpreadLove\n\n<3 GRiZ',
#     'country': 'United States',
#     'track_count': 367,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 15296,
#     'followings_count': 657,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'Official Site',
#     'website': 'http://www.mynameisGRiZ.com',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 42,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/griz/coast-2-coast-ft-flowdan?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-t395Pz5GeAcL-0-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2119828623/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/orGUrFie8QeS_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 267495,
#    'download_count': 0,
#    'favoritings_count': 14385,
#    'reposts_count': 548,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'GRiZ, Flowdan'},
#   {'kind': 'track',
#    'id': 2130995139,
#    'urn': 'soundcloud:tracks:2130995139',
#    'created_at': '2025/07/16 14:09:34 +0000',
#    'duration': 214073,
#    'commentable': True,
#    'comment_count': 88,
#    'sharing': 'public',
#    'tag_list': ' dubstep bass music weird wonky riddim "wizard council" hairitage',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://ffm.to/swhbrainwaves',
#    'purchase_title': None,
#    'genre': 'Dubstep',
#    'title': 'Space Wizard & Hairitage - Brainwaves',
#    'description': '@hairitage\n\nart by \nhttps://www.instagram.com/r.a_marsh/\n\nthanks for listening ',
#    'label_name': 'Wizard Council Recordings',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'QZWFF2528191',
#    'bpm': None,
#    'release_year': None,
#    'release_month': None,
#    'release_day': None,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2130995139',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-2niRZZ4KaB7G3IsB-Cv2YZw-large.jpg',
#     'id': 57790806,
#     'urn': 'soundcloud:users:57790806',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/space_wizard_music?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:57790806',
#     'username': 'Space Wizard',
#     'permalink': 'space_wizard_music',
#     'created_at': '2013/09/12 07:11:47 +0000',
#     'last_modified': '2025/10/17 16:28:40 +0000',
#     'first_name': '',
#     'last_name': '',
#     'full_name': '',
#     'city': '',
#     'description': 'welcome to the wizard council🧙\u200d♂️',
#     'country': None,
#     'track_count': 67,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 1557,
#     'followings_count': 861,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': None,
#     'website': None,
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 51,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/space_wizard_music/space-wizard-hairitage-brainwaves?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-MschXyf5ru169Fz1-pSldzw-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2130995139/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/8qkhBrKlSYX8_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 60800,
#    'download_count': 0,
#    'favoritings_count': 3893,
#    'reposts_count': 142,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'Space Wizard, Hairitage'},
#   {'kind': 'track',
#    'id': 2112463860,
#    'urn': 'soundcloud:tracks:2112463860',
#    'created_at': '2025/06/12 23:39:15 +0000',
#    'duration': 357042,
#    'commentable': True,
#    'comment_count': 0,
#    'sharing': 'public',
#    'tag_list': ' "Drum\'n\'Bass / Jungle"',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': None,
#    'purchase_title': None,
#    'genre': 'Electronic',
#    'title': 'With You (VIP)',
#    'description': None,
#    'label_name': 'Strange Bass',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'QMBZ92526089',
#    'bpm': None,
#    'release_year': 2025,
#    'release_month': 7,
#    'release_day': 14,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2112463860',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-j4HTZVvvoDMVe427-70nfzw-large.jpg',
#     'id': 5844386,
#     'urn': 'soundcloud:users:5844386',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/lamebot_music?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:5844386',
#     'username': 'LAMEBOT_Music',
#     'permalink': 'lamebot_music',
#     'created_at': '2011/07/08 23:05:05 +0000',
#     'last_modified': '2023/08/05 09:23:24 +0000',
#     'first_name': '',
# ...
#     'last_modified': '2025/11/14 17:17:49 +0000',
#     'first_name': '',
#     'last_name': '',
#     'full_name': '',
#     'city': 'Camp Crystal Lake',
#     'description': 'welcome to the wasteland🌪️\n\nALL ENQUIRIES:\ncontact.doilmusic@gmail.com\n\n@rudeservice \n@bassweightrec\n@welcome-recs\n@subsidia\n@circusrecords\n@emengy',
#     'country': None,
#     'track_count': 37,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 6230,
#     'followings_count': 953,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'TWITTER',
#     'website': 'https://x.com/doilmusic',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 50,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/officialdoil/doil-island-flip?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-X5YapT1DlffMyKSM-6lwI9A-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2121020505/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/ULHD8Nk09LBL_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 15170,
#    'download_count': 0,
#    'favoritings_count': 1125,
#    'reposts_count': 379,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'DOIL'},
#   {'kind': 'track',
#    'id': 2118661617,
#    'urn': 'soundcloud:tracks:2118661617',
#    'created_at': '2025/06/24 11:41:07 +0000',
#    'duration': 160026,
#    'commentable': True,
#    'comment_count': 139,
#    'sharing': 'public',
#    'tag_list': ' EDM DANCE DUBSTEP Electronic REMIX TRANCE RIDDIM HARDSTYLE HEADBANG HEADBANGER "LADY GAGA" ENERGETIC "DEEP DUBSTEP"',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://hypeddit.com/cobalt/abracadabracobaltflip',
#    'purchase_title': 'Free Download',
#    'genre': 'Dubstep',
#    'title': 'LADY GAGA - ABRACADABRA (COBALT FLIP)',
#    'description': 'Wrapping up Pride Month with this BANGER!',
#    'label_name': '',
#    'release': None,
#    'key_signature': None,
#    'isrc': None,
#    'bpm': None,
#    'release_year': None,
#    'release_month': None,
#    'release_day': None,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2118661617',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-zN8LCu6BcCbeCEzr-X7yGww-large.jpg',
#     'id': 705923746,
#     'urn': 'soundcloud:users:705923746',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/cobaltdubz?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:705923746',
#     'username': 'COBALT',
#     'permalink': 'cobaltdubz',
#     'created_at': '2019/09/23 00:55:30 +0000',
#     'last_modified': '2025/10/31 04:50:29 +0000',
#     'first_name': '',
#     'last_name': '',
#     'full_name': '',
#     'city': 'Denver, CO',
#     'description': '🧿 WELCOME THE ORDER OF THE EYE 🧿\nDubstep DJ/producer based in Denver, CO\n\nhttps://linktr.ee/cobaltdubz\nBooking/Info: cobaltdubz@gmail.com',
#     'country': 'United States',
#     'track_count': 34,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 2713,
#     'followings_count': 605,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': None,
#     'website': None,
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 11,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/cobaltdubz/lady-gaga-abracadabra-cobalt-1?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-y0OcU0DopLCwThbS-sm04OA-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2118661617/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/Jhy4LrOeZ2Ll_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 5337,
#    'download_count': 0,
#    'favoritings_count': 379,
#    'reposts_count': 94,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'COBALT'},
#   {'kind': 'track',
#    'id': 2135134740,
#    'urn': 'soundcloud:tracks:2135134740',
#    'created_at': '2025/07/23 15:00:04 +0000',
#    'duration': 220317,
#    'commentable': True,
#    'comment_count': 33,
#    'sharing': 'public',
#    'tag_list': ' ',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://dramaclub.ffm.to/whatuwantep',
#    'purchase_title': 'STREAM & DOWNLOAD',
#    'genre': 'Dubstep',
#    'title': 'Boogie T & ill.Gates - Trash Bandicoot',
#    'description': '‘WhatUWant EP’ OUT NOW ➤ https://dramaclub.ffm.to/whatuwantep\n\nSupport @boogietmusic\nhttps://www.instagram.com/mrboogiet\nhttps://www.twitter.com/boogietmusic\nhttps://www.facebook.com/boogietmusic\nhttps://www.tiktok.com/@mrboogiet\nhttps://open.spotify.com/artist/4zlw0jXUzd4dRcqI3Y1OiY?si=GfQLqWaQSauDJsBlWCFg1g\n\nSupport @ill-gates\nhttps://www.instagram.com/illgatesmusic\nhttps://www.twitter.com/illgatesmusic\nhttps://www.facebook.com/illGatesMusic\nhttps://www.tiktok.com/@illgates\nhttps://www.youtube.com/illgatesmusic\nhttps://open.spotify.com/artist/4a32m0kHbxZm3V7jHpW60g?si=lzgdkEjlRheGFt4UR2kkzQ\n\nSupport @dramaclubrecs\nhttps://www.instagram.com/dramaclubrecs\nhttps://www.twitter.com/dramaclubrecs\nhttps://www.facebook.com/dramaclubrecs\nhttps://www.youtube.com/@DramaClubRecs\nhttps://www.twitch.tv/dramaclubTV',
#    'label_name': 'Drama Club Recordings',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'CA5KR2542785',
#    'bpm': None,
#    'release_year': 2025,
#    'release_month': 7,
#    'release_day': 23,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2135134740',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-000182465039-x7g8r4-large.jpg',
#     'id': 5471863,
#     'urn': 'soundcloud:users:5471863',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/boogietmusic?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:5471863',
#     'username': 'Boogie T',
#     'permalink': 'boogietmusic',
#     'created_at': '2011/06/20 19:59:15 +0000',
#     'last_modified': '2025/11/17 17:27:03 +0000',
#     'first_name': 'Brock',
#     'last_name': 'Thornton',
#     'full_name': 'Brock Thornton',
#     'city': 'New Orleans, LA',
#     'description': 'Producer/DJ from New Orleans, Louisiana\n\nMANAGEMENT:\nboogiet@redlightmanagement.com\n\nBOOKINGS:\njake.bernstein@teamwass.com',
#     'country': 'United States',
#     'track_count': 112,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 3327,
#     'followings_count': 364,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'BoogieT.net',
#     'website': 'https://boogiet.net/',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 12,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/boogietmusic/trash-bandicoot?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-rV0TIyyCW4RtqB7a-5wWZrQ-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2135134740/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/udMqKmygZ41T_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 23574,
#    'download_count': 0,
#    'favoritings_count': 1464,
#    'reposts_count': 73,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'Boogie T, ill.Gates'},
#   {'kind': 'track',
#    'id': 2135134734,
#    'urn': 'soundcloud:tracks:2135134734',
#    'created_at': '2025/07/23 15:00:04 +0000',
#    'duration': 221179,
#    'commentable': True,
#    'comment_count': 43,
#    'sharing': 'public',
#    'tag_list': ' ',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://dramaclub.ffm.to/whatuwantep',
#    'purchase_title': 'STREAM & DOWNLOAD',
#    'genre': 'Dubstep',
#    'title': 'Boogie T & ill.Gates - WhatUWant',
#    'description': '‘WhatUWant EP’ OUT NOW ➤ https://dramaclub.ffm.to/whatuwantep\n\nSupport @boogietmusic\nhttps://www.instagram.com/mrboogiet\nhttps://www.twitter.com/boogietmusic\nhttps://www.facebook.com/boogietmusic\nhttps://www.tiktok.com/@mrboogiet\nhttps://open.spotify.com/artist/4zlw0jXUzd4dRcqI3Y1OiY?si=GfQLqWaQSauDJsBlWCFg1g\n\nSupport @ill-gates\nhttps://www.instagram.com/illgatesmusic\nhttps://www.twitter.com/illgatesmusic\nhttps://www.facebook.com/illGatesMusic\nhttps://www.tiktok.com/@illgates\nhttps://www.youtube.com/illgatesmusic\nhttps://open.spotify.com/artist/4a32m0kHbxZm3V7jHpW60g?si=lzgdkEjlRheGFt4UR2kkzQ\n\nSupport @dramaclubrecs\nhttps://www.instagram.com/dramaclubrecs\nhttps://www.twitter.com/dramaclubrecs\nhttps://www.facebook.com/dramaclubrecs\nhttps://www.youtube.com/@DramaClubRecs\nhttps://www.twitch.tv/dramaclubTV',
#    'label_name': 'Drama Club Recordings',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'CA5KR2542787',
#    'bpm': None,
#    'release_year': 2025,
#    'release_month': 7,
#    'release_day': 23,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2135134734',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-000182465039-x7g8r4-large.jpg',
#     'id': 5471863,
#     'urn': 'soundcloud:users:5471863',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/boogietmusic?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:5471863',
#     'username': 'Boogie T',
#     'permalink': 'boogietmusic',
#     'created_at': '2011/06/20 19:59:15 +0000',
#     'last_modified': '2025/11/17 17:27:03 +0000',
#     'first_name': 'Brock',
#     'last_name': 'Thornton',
#     'full_name': 'Brock Thornton',
#     'city': 'New Orleans, LA',
#     'description': 'Producer/DJ from New Orleans, Louisiana\n\nMANAGEMENT:\nboogiet@redlightmanagement.com\n\nBOOKINGS:\njake.bernstein@teamwass.com',
#     'country': 'United States',
#     'track_count': 112,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 3327,
#     'followings_count': 364,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'BoogieT.net',
#     'website': 'https://boogiet.net/',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 12,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/boogietmusic/whatuwant?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-rV0TIyyCW4RtqB7a-5wWZrQ-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2135134734/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/BRy4ebN9NDxl_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 20014,
#    'download_count': 0,
#    'favoritings_count': 1333,
#    'reposts_count': 72,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'Boogie T, ill.Gates'},
#   {'kind': 'track',
#    'id': 2132132964,
#    'urn': 'soundcloud:tracks:2132132964',
#    'created_at': '2025/07/18 02:56:32 +0000',
#    'duration': 195474,
#    'commentable': True,
#    'comment_count': 106,
#    'sharing': 'public',
#    'tag_list': ' ',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': 'https://deadbeats.lnk.to/Collected',
#    'purchase_title': 'Stream/Download',
#    'genre': 'Dance',
#    'title': 'Collected',
#    'description': '',
#    'label_name': 'Deadbeats',
#    'release': None,
#    'key_signature': None,
#    'isrc': 'USZXT2557356',
#    'bpm': None,
#    'release_year': 2025,
#    'release_month': 7,
#    'release_day': 25,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2132132964',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-11RtQzOlbd741oaf-fb25zw-large.jpg',
#     'id': 1146824059,
#     'urn': 'soundcloud:users:1146824059',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/phrva?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:1146824059',
#     'username': 'Phrva',
#     'permalink': 'phrva',
#     'created_at': '2022/07/28 03:49:32 +0000',
#     'last_modified': '2025/10/10 20:12:50 +0000',
#     'first_name': '',
#     'last_name': '',
#     'full_name': '',
#     'city': 'Los Angeles',
#     'description': '[fər-və]\n\na desire burns\n\nMGMT: jess@radishmgmt.com // anthony@radishmgmt.com\nNA Bookings: perry.gilman@unitedtalent.com // kayla.morgan@unitedtalent.com',
#     'country': None,
#     'track_count': 36,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 0,
#     'followings_count': 0,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': None,
#     'website': None,
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 6,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/phrva/collected-1?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-8jDDXI6TQGY3-0-large.jpg',
#    'stream_url': None,
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/TNjs6MVsieU6_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 60253,
#    'download_count': 0,
#    'favoritings_count': 4272,
#    'reposts_count': 321,
#    'downloadable': False,
#    'access': 'blocked',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'Phrva, Don Jamal, Rakjay'}],
#  'user.avatar_url': 'https://i1.sndcdn.com/avatars-000508611474-jcr23a-large.jpg',
#  'user.id': 15999805,
#  'user.urn': 'soundcloud:users:15999805',
#  'user.kind': 'user',
#  'user.permalink_url': 'https://soundcloud.com/kevinbigfoot?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#  'user.uri': 'https://api.soundcloud.com/users/soundcloud:users:15999805',
#  'user.username': 'Kevin',
#  'user.permalink': 'kevinbigfoot',
#  'user.created_at': '2012/04/28 04:18:19 +0000',
#  'user.last_modified': '2025/03/17 20:28:29 +0000',
#  'user.first_name': 'Kevin',
#  'user.last_name': 'Andrews',
#  'user.full_name': 'Kevin Andrews',
#  'user.city': 'Seattle',
#  'user.description': None,
#  'user.country': 'United States',
#  'user.track_count': 17,
#  'user.public_favorites_count': 0,
#  'user.reposts_count': 0,
#  'user.followers_count': 0,
#  'user.followings_count': 0,
#  'user.plan': 'Pro Unlimited',
#  'user.myspace_name': None,
#  'user.discogs_name': None,
#  'user.website_title': 'Mixcloud',
#  'user.website': 'http://www.mixcloud.com/K3VB0T/',
#  'user.comments_count': 0,
#  'user.online': False,
#  'user.likes_count': 0,
#  'user.playlist_count': 154,
#  'user.subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#     'name': 'Pro Unlimited'}}]}

# %%
df.iloc[0].to_dict()
# Out:
# {'duration': 3294485,
#  'genre': '',
#  'release_day': None,
#  'permalink': 'long-tracks',
#  'permalink_url': 'https://soundcloud.com/kevinbigfoot/sets/long-tracks/s-D9RU9imJ0Ir?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#  'release_month': None,
#  'release_year': None,
#  'description': None,
#  'uri': 'https://api.soundcloud.com/playlists/soundcloud:playlists:2114893679?secret_token=s-D9RU9imJ0Ir',
#  'label_name': None,
#  'label_id': None,
#  'label': None,
#  'tag_list': '',
#  'track_count': 1,
#  'user_id': 15999805,
#  'user_urn': 'soundcloud:users:15999805',
#  'last_modified': '2025/11/15 21:13:44 +0000',
#  'license': 'all-rights-reserved',
#  'playlist_type': 'PLAYLIST',
#  'type': 'PLAYLIST',
#  'id': 2114893679,
#  'urn': 'soundcloud:playlists:2114893679',
#  'downloadable': None,
#  'likes_count': 0,
#  'repost_count': 0,
#  'sharing': 'private',
#  'created_at': '2025/11/15 21:13:44 +0000',
#  'release': None,
#  'tags': '',
#  'kind': 'playlist',
#  'title': 'Long Tracks',
#  'purchase_title': None,
#  'ean': None,
#  'streamable': True,
#  'embeddable_by': 'all',
#  'artwork_url': None,
#  'purchase_url': None,
#  'tracks_uri': 'https://api.soundcloud.com/playlists/soundcloud:playlists:2114893679/tracks?secret_token=s-D9RU9imJ0Ir',
#  'secret_token': 's-D9RU9imJ0Ir',
#  'secret_uri': 'https://api.soundcloud.com/playlists/soundcloud:playlists:2114893679?secret_token=s-D9RU9imJ0Ir',
#  'tracks': [{'kind': 'track',
#    'id': 2184037855,
#    'urn': 'soundcloud:tracks:2184037855',
#    'created_at': '2025/10/07 03:26:13 +0000',
#    'duration': 3294485,
#    'commentable': True,
#    'comment_count': 97,
#    'sharing': 'public',
#    'tag_list': ' slick slicko mode vol 7 mix trap dubstep wave bass 2025 music edm workout gym remix edit edc ultra',
#    'streamable': True,
#    'embeddable_by': 'all',
#    'purchase_url': None,
#    'purchase_title': None,
#    'genre': 'Trap',
#    'title': 'SLICKO MODE VOL. 7',
#    'description': 'i hope you all enjoy this hour-long mix full of brand new music from the homies and i!\n\nTRACKLIST: https://www.1001tracklists.com/tracklist/unhcqb1/slick-slicko-mode-vol.-7-2025-10-07.html#edit\n\nFollow SLICK:\nSoundcloud: @djslickmusic\nSpotify: open.spotify.com/artist/0AwoMepzmoVrEsWXft8Pe2\nInstagram: www.instagram.com/slickmusic_\nTwitter: www.twitter.com/slickmusic_\nYouTube: www.youtube.com/@slick91\nTikTok: www.tiktok.com/@slickmusic_',
#    'label_name': '',
#    'release': None,
#    'key_signature': None,
#    'isrc': None,
#    'bpm': None,
#    'release_year': None,
#    'release_month': None,
#    'release_day': None,
#    'license': 'all-rights-reserved',
#    'uri': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2184037855',
#    'user': {'avatar_url': 'https://i1.sndcdn.com/avatars-X4PUsdUwdATlyZFU-2xfEPA-large.jpg',
#     'id': 541727514,
#     'urn': 'soundcloud:users:541727514',
#     'kind': 'user',
#     'permalink_url': 'https://soundcloud.com/djslickmusic?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#     'uri': 'https://api.soundcloud.com/users/soundcloud:users:541727514',
#     'username': 'SLICK',
#     'permalink': 'djslickmusic',
#     'created_at': '2018/11/17 18:37:25 +0000',
#     'last_modified': '2025/11/14 01:19:00 +0000',
#     'first_name': '',
#     'last_name': '',
#     'full_name': '',
#     'city': '',
#     'description': 'all inquiries: djslickmgmt@gmail.com\n\nhttps://linktr.ee/slickmusic',
#     'country': None,
#     'track_count': 36,
#     'public_favorites_count': 0,
#     'reposts_count': 0,
#     'followers_count': 15466,
#     'followings_count': 96,
#     'plan': 'Pro Unlimited',
#     'myspace_name': None,
#     'discogs_name': None,
#     'website_title': 'tiktok',
#     'website': 'https://www.tiktok.com/@slickmusic_',
#     'comments_count': 0,
#     'online': False,
#     'likes_count': 0,
#     'playlist_count': 5,
#     'subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#        'name': 'Pro Unlimited'}}]},
#    'permalink_url': 'https://soundcloud.com/djslickmusic/slicko-mode-vol-7?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#    'artwork_url': 'https://i1.sndcdn.com/artworks-7KZVXpND6CUKD2C4-4d3Qqw-large.jpg',
#    'stream_url': 'https://api.soundcloud.com/tracks/soundcloud:tracks:2184037855/stream',
#    'download_url': None,
#    'waveform_url': 'https://wave.sndcdn.com/fzHZrmGtrASg_m.png',
#    'available_country_codes': None,
#    'secret_uri': None,
#    'user_favorite': False,
#    'user_playback_count': 1,
#    'playback_count': 17014,
#    'download_count': 0,
#    'favoritings_count': 1273,
#    'reposts_count': 106,
#    'downloadable': False,
#    'access': 'playable',
#    'policy': None,
#    'monetization_model': None,
#    'metadata_artist': 'SLICK'}],
#  'user.avatar_url': 'https://i1.sndcdn.com/avatars-000508611474-jcr23a-large.jpg',
#  'user.id': 15999805,
#  'user.urn': 'soundcloud:users:15999805',
#  'user.kind': 'user',
#  'user.permalink_url': 'https://soundcloud.com/kevinbigfoot?utm_medium=api&utm_campaign=social_sharing&utm_source=id_318266',
#  'user.uri': 'https://api.soundcloud.com/users/soundcloud:users:15999805',
#  'user.username': 'Kevin',
#  'user.permalink': 'kevinbigfoot',
#  'user.created_at': '2012/04/28 04:18:19 +0000',
#  'user.last_modified': '2025/03/17 20:28:29 +0000',
#  'user.first_name': 'Kevin',
#  'user.last_name': 'Andrews',
#  'user.full_name': 'Kevin Andrews',
#  'user.city': 'Seattle',
#  'user.description': None,
#  'user.country': 'United States',
#  'user.track_count': 17,
#  'user.public_favorites_count': 0,
#  'user.reposts_count': 0,
#  'user.followers_count': 0,
#  'user.followings_count': 0,
#  'user.plan': 'Pro Unlimited',
#  'user.myspace_name': None,
#  'user.discogs_name': None,
#  'user.website_title': 'Mixcloud',
#  'user.website': 'http://www.mixcloud.com/K3VB0T/',
#  'user.comments_count': 0,
#  'user.online': False,
#  'user.likes_count': 0,
#  'user.playlist_count': 154,
#  'user.subscriptions': [{'product': {'id': 'creator-pro-unlimited',
#     'name': 'Pro Unlimited'}}]}

# %%
# Fetch first 200 tracks directly (one API call)
print("Fetching first 200 SoundCloud tracks...")

token_data = state.cache.get("token_data")
access_token = token_data["access_token"]

# Single API request for first page
import requests

url = "https://api.soundcloud.com/me/likes/tracks"
headers = {"Authorization": f"OAuth {access_token}"}
params = {
    "limit": 200,
    "linked_partitioning": True,
}

response = requests.get(url, params=params, headers=headers, timeout=30)
response.raise_for_status()
data = response.json()

# Parse tracks
sc_tracks = []
if "collection" in data:
    for item in data["collection"]:
        # Filter to only tracks (API may return other kinds)
        if not item or item.get("kind") != "track":
            continue

        track_id = str(item["id"])
        metadata = soundcloud._normalize_soundcloud_track(item)
        sc_tracks.append((track_id, metadata))

# Filter Out First 31
sc_tracks = sc_tracks[31:]

print(f"✓ Fetched {len(sc_tracks)} tracks from first page")
print(f"\nFirst 3:")
for track_id, metadata in sc_tracks[:3]:
    print(f"  {metadata.get('artist')} - {metadata.get('title')} (ID: {track_id})")
# Out:
# Fetching first 200 SoundCloud tracks...
# ✓ Fetched 169 tracks from first page
#
# First 3:
#   Wakaan - Capochino - Hypnotic (ID: 2172046062)
#   Shroom - Young Miko - Wassup (Shroom x UrBoiN8 Flip) (ID: 2176339092)
#   Kompany - Jackpot (Space Wizard Remix) (ID: 2192107907)

# %%
df = pd.DataFrame(data["collection"])

print(df.iloc[0])
# Out:
# kind                                                                   track
# id                                                                2211704240
# urn                                             soundcloud:tracks:2211704240
# created_at                                         2025/11/13 07:20:43 +0000
# duration                                                              167471
# commentable                                                             True
# comment_count                                                             14
# sharing                                                               public
# tag_list                                              drumstep "Drum & Bass"
# streamable                                                              True
# embeddable_by                                                            all
# purchase_url                    https://hypeddit.com/thelivingproof/feelthis
# purchase_title                                                          None
# genre                                                                Dubstep
# title                                                              FEEL THIS
# description                CLICK CLICK WHO THE F*** WANNA FEEL THIS\n\nht...
# label_name
# release                                                                 None
# key_signature                                                           None
# isrc                                                            QZZ8B2551884
# bpm                                                                     None
# release_year                                                             NaN
# release_month                                                            NaN
# release_day                                                              NaN
# license                                                  all-rights-reserved
# uri                        https://api.soundcloud.com/tracks/soundcloud:t...
# user                       {'avatar_url': 'https://i1.sndcdn.com/avatars-...
# permalink_url              https://soundcloud.com/thelivingproofmusic/the...
# artwork_url                https://i1.sndcdn.com/artworks-biNZmighuASrBr8...
# stream_url                 https://api.soundcloud.com/tracks/soundcloud:t...
# download_url                                                            None
# waveform_url                      https://wave.sndcdn.com/zpVKMbIISV4v_m.png
# available_country_codes                                                 None
# secret_uri                                                              None
# user_favorite                                                          False
# user_playback_count                                                        1
# playback_count                                                          2882
# download_count                                                             0
# favoritings_count                                                        247
# reposts_count                                                             57
# downloadable                                                           False
# access                                                              playable
# policy                                                                  None
# monetization_model                                                      None
# metadata_artist                                             The Living Proof
# Name: 0, dtype: object

# %% [markdown]
# ## 4. Load Local Tracks (Without SoundCloud ID)

# %%
# Get all tracks from database
all_tracks = database.get_all_tracks()

# Filter to only local tracks WITHOUT soundcloud_id
local_tracks = [
    t for t in all_tracks if t.get("local_path") and not t.get("soundcloud_id")
]

print(f"Total tracks in DB: {len(all_tracks)}")
print(f"Local tracks without SoundCloud ID: {len(local_tracks)}")
print(f"\nFirst 3 local tracks:")
for track in local_tracks[:3]:
    print(f"  {track.get('artist')} - {track.get('title')}")
# Out:
# Total tracks in DB: 5415
# Local tracks without SoundCloud ID: 5415
#
# First 3 local tracks:
#   None - MergeFX Sample Sound 202
#   None - MergeFX Sample Sound 203
#   None - MergeFX Sample Sound 204

# %% [markdown]
# ## 5. Run Matching Process

# %% [markdown]
# ### 5.1 Test Case: BAWDY Track (Should Now Match!)

# %% [markdown]
# ### 5.2 Full Matching with Scores

# %%
# TF-IDF batch matching - MUCH faster!
print("=" * 80)
print("TF-IDF SEARCH-BASED MATCHING")
print("=" * 80)
print(
    f"Matching {len(sc_tracks)} SC tracks against {len(local_tracks)} local tracks..."
)
print()

# Time the matching
start_time = time.time()

# Call TF-IDF matcher (batch operation)
tfidf_results = find_best_matches_tfidf(sc_tracks, local_tracks, min_score=0.70)

elapsed = time.time() - start_time

# Process results
matches_tfidf = []
no_matches_tfidf = []

for sc_id, best_match, score in tfidf_results:
    sc_metadata = next(meta for tid, meta in sc_tracks if tid == sc_id)

    if best_match:
        matches_tfidf.append(
            {
                "sc_id": sc_id,
                "sc_title": sc_metadata.get("title"),
                "sc_artist": sc_metadata.get("artist"),
                "local_id": best_match["id"],
                "local_title": best_match.get("title"),
                "local_artist": best_match.get("artist"),
                "score": score,
            }
        )
    else:
        no_matches_tfidf.append(
            {
                "sc_id": sc_id,
                "title": sc_metadata.get("title"),
                "artist": sc_metadata.get("artist"),
                "genre": sc_metadata.get("genre"),
                "best_score": score,
            }
        )

print(f"✓ Matching complete in {elapsed:.2f} seconds!")
print()
print(f"  Matched (>= 0.70): {len(matches_tfidf)}")
print(f"  No match (< 0.70):  {len(no_matches_tfidf)}")
print()

if matches_tfidf:
    scores = [m["score"] for m in matches_tfidf]
    print(f"Score distribution:")
    print(f"  Average:  {sum(scores) / len(scores):.3f}")
    print(f"  Min:      {min(scores):.3f}")
    print(f"  Max:      {max(scores):.3f}")
    print()
    print(f"  High (0.9-1.0):      {sum(1 for s in scores if s >= 0.9)} tracks")
    print(f"  Good (0.8-0.89):     {sum(1 for s in scores if 0.8 <= s < 0.9)} tracks")
    print(f"  Moderate (0.7-0.79): {sum(1 for s in scores if 0.7 <= s < 0.8)} tracks")
# Out:
# ================================================================================
# TF-IDF SEARCH-BASED MATCHING
# ================================================================================
# Matching 169 SC tracks against 5415 local tracks...
#
# ✓ Matching complete in 0.31 seconds!
#
#   Matched (>= 0.70): 149
#   No match (< 0.70):  20
#
# Score distribution:
#   Average:  0.923
#   Min:      0.702
#   Max:      0.995
#
#   High (0.9-1.0):      113 tracks
#   Good (0.8-0.89):     27 tracks
#   Moderate (0.7-0.79): 9 tracks

# %% [markdown]
# # Apply manual corrections if CSV has been edited
# corrections_file = '/home/kevin/coding/music-minion-cli/soundcloud_matches_review.csv'
#
# # Convert matches_tfidf list to dict format for correction function
# matches_dict = matches_tfidf.copy()
#
# # Apply corrections
# corrected_matches = apply_manual_corrections(matches_dict, corrections_file)
#
# # Count changes
# corrected_count = sum(1 for m in corrected_matches if m.get('corrected', False))
# removed_count = len(matches_dict) - len(corrected_matches)
#
# if corrected_count > 0 or removed_count > 0:
#     print(f"\n📊 Correction summary:")
#     if corrected_count > 0:
#         print(f"  ✓ {corrected_count} matches corrected (replaced with correct track ID)")
#     if removed_count > 0:
#         print(f"  ✗ {removed_count} matches removed (marked as 'None' - no valid match)")
#
#     print(f"\n  Total matches: {len(matches_dict)} → {len(corrected_matches)}")
#
#     if corrected_count > 0:
#         print("\nCorrected matches:")
#         for m in corrected_matches:
#             if m.get('corrected'):
#                 print(f"  {m['sc_artist']} - {m['sc_title']}")
#                 print(f"    → {m['local_artist']} - {m['local_title']} (ID: {m['local_id']})")
# else:
#     print("\nℹ️  No corrections applied (CSV not edited or no correct_id values filled)")

# %%
# Apply manual corrections if CSV has been edited
corrections_file = "/home/kevin/coding/music-minion-cli/soundcloud_matches_review.csv"

# Convert matches_tfidf list to dict format for correction function
matches_dict = matches_tfidf.copy()

# Apply corrections
corrected_matches = apply_manual_corrections(matches_dict, corrections_file)

# Count how many were corrected
corrected_count = sum(1 for m in corrected_matches if m.get("corrected", False))

if corrected_count > 0:
    print(f"\n✓ {corrected_count} matches were corrected based on CSV")
    print("\nCorrected matches:")
    for m in corrected_matches:
        if m.get("corrected"):
            print(f"  {m['sc_artist']} - {m['sc_title']}")
            print(
                f"    → {m['local_artist']} - {m['local_title']} (ID: {m['local_id']})"
            )
else:
    print("\nℹ️  No corrections applied (CSV not edited or no correct_id values filled)")

# %%
# Export matches to CSV for manual review and correction
df_review = pd.DataFrame(matches_tfidf)

# Add empty column for manual corrections
df_review["correct_id"] = ""
df_review["notes"] = ""

# Sort by score (lowest first) - these need the most attention
df_review_sorted = df_review.sort_values("score")

# Save to CSV
output_file = "/home/kevin/coding/music-minion-cli/soundcloud_matches_review.csv"
df_review_sorted.to_csv(output_file, index=False)

print(f"✓ Exported {len(df_review)} matches to:")
print(f"  {output_file}")
print()
print("Review instructions:")
print("1. Open CSV and sort by 'score' (lowest first)")
print("2. For incorrect matches, look up the correct track ID")
print("3. Fill in 'correct_id' column with the right ID")
print("4. Add notes explaining why it was wrong (optional)")
print("5. Save and re-run notebook to apply corrections")
print()
print(f"Bottom 10 matches (need review):")
print()
display(
    df_review_sorted[
        ["sc_artist", "sc_title", "local_artist", "local_title", "score", "correct_id"]
    ].head(10)
)

# %%
# Check if BAWDY track matched
bawdy_matches = [m for m in matches_tfidf if m["sc_artist"] == "BAWDY"]

print("=" * 80)
print("BAWDY TRACK TEST - TF-IDF Results")
print("=" * 80)
print()

if bawdy_matches:
    print(f"✅ Found {len(bawdy_matches)} BAWDY match(es)!")
    print()
    for match in bawdy_matches:
        print(f"SoundCloud: {match['sc_artist']} - {match['sc_title']}")
        print(f"Local:      {match['local_artist']} - {match['local_title']}")
        print(f"Score:      {match['score']:.3f}")
        print()
else:
    print("❌ BAWDY track did NOT match")
    print()
    # Show what it got instead
    bawdy_in_no_matches = [nm for nm in no_matches_tfidf if nm["artist"] == "BAWDY"]
    if bawdy_in_no_matches:
        for nm in bawdy_in_no_matches:
            print(f"  {nm['artist']} - {nm['title']}")
            print(
                f"  Best score: {nm.get('best_score', 0.0):.3f} (below 0.70 threshold)"
            )

# %%
track
# Out:
# ('2211704240', {'title': 'FEEL THIS', 'artist': 'The Living Proof', 'genre': 'Dubstep', 'duration': 167.471})

# %%
df = pd.DataFrame(local_tracks)
display(df.head(1))

display(df[df.title.str.contains("MY NECK MY BACK")])
# Out:
#      id                                          file_path  \
# 0  6039  /home/kevin/Music/PioneerDJ/Sampler/MERGE FX/M...
#
#                       title artist album genre  year  duration key_signature  \
# 0  MergeFX Sample Sound 202   None  None  None   NaN  1.838073          None
#
#    bpm  ...    file_mtime       last_synced_at  remix_artist  \
# 0  NaN  ...  1.602181e+09  2025-11-19 01:22:49          None
#
#                                           local_path soundcloud_id spotify_id  \
# 0  /home/kevin/Music/PioneerDJ/Sampler/MERGE FX/M...          None       None
#
#   youtube_id soundcloud_synced_at spotify_synced_at youtube_synced_at
# 0       None                 None              None              None
#
# [1 rows x 22 columns]
#        id                                          file_path  \
# 321  3457  /home/kevin/Music/EDM/2020/Aug 20/MY NECK MY B...
# 333  5896  /home/kevin/Music/EDM/2025/Sept 25/MY NECK MY ...
#
#                                                  title              artist  \
# 321  MY NECK MY BACK - (BAD TASTES TOO WOOK TO WALK...  BADTASTES OFFICIAL
# 333                       MY NECK MY BACK (BAWDY Flip)               BAWDY
#
#        album genre    year    duration key_signature    bpm  ...  \
# 321   Aug 20  Trap  2018.0  158.979200           G#m   73.0  ...
# 333  Sept 25  Trap  2025.0  138.087506            Cm  100.0  ...
#
#        file_mtime       last_synced_at  remix_artist  \
# 321  1.751567e+09  2025-11-19 01:22:49          None
# 333  1.759638e+09  2025-11-19 01:22:49         BAWDY
#
#                                             local_path soundcloud_id  \
# 321  /home/kevin/Music/EDM/2020/Aug 20/MY NECK MY B...          None
# 333  /home/kevin/Music/EDM/2025/Sept 25/MY NECK MY ...          None
#
#     spotify_id youtube_id soundcloud_synced_at spotify_synced_at  \
# 321       None       None                 None              None
# 333       None       None                 None              None
#
#     youtube_synced_at
# 321              None
# 333              None
#
# [2 rows x 22 columns]

# %%
df = pd.DataFrame([t[1] for t in sc_tracks])
df.insert(0, "id", [t[0] for t in sc_tracks])
display(df[df.artist == "BAWDY"].tail(1))
# Out:
#              id                                   title artist   genre  \
# 196  2091674085  MY NECK MY BACK (BAWDY Flip) (FREE DL)  BAWDY  100bpm
#
#      duration
# 196   138.136

# %%
print(len(sc_tracks))
# Out:
# 200

# %%
all_playlists.extend(data)
# Find target playlists
target_names = ["Nov 25", "Oct 25", "Sept 25"]
target_playlists = {}

for playlist in all_playlists:
    name = playlist.get("title", "")

    if name in target_names:
        target_playlists[name] = {
            "id": str(playlist["id"]),
            "track_count": playlist.get("track_count", 0),
            "tracks": playlist.get("tracks", []),
        }

print(f"\nFound target playlists:")
for name in target_names:
    if name in target_playlists:
        pl = target_playlists[name]
        print(f"  ✓ {name}: {pl['track_count']} tracks (ID: {pl['id']})")
    else:
        print(f"  ✗ {name}: Not found")
# Out:
# Found target playlists:
#   ✓ Nov 25: 31 tracks (ID: 2107077439)
#   ✓ Oct 25: 71 tracks (ID: 2089957919)
#   ✓ Sept 25: 154 tracks (ID: 2076808602)

# %% [markdown]
# ### Compare: Likes NOT in Playlists

# %% [markdown]
# ## 5. Results Analysis

# %% [markdown]
# ### 5.1 Matched Tracks Table (Top 20)

# %% [markdown]
# ### 5.2 Borderline Matches (0.8-0.85) - Needs Manual Verification

# %%
if matches:
    df_borderline = df_matches[
        (df_matches["score"] >= 0.8) & (df_matches["score"] < 0.85)
    ]

    print(f"Borderline matches (0.8-0.85): {len(df_borderline)} tracks")
    print("These should be manually verified:")
    print()

    if len(df_borderline) > 0:
        display(
            df_borderline[
                ["sc_artist", "sc_title", "local_artist", "local_title", "score"]
            ]
        )
    else:
        print("✓ No borderline matches - all matches are high confidence!")

# %% [markdown]
# ### 5.3 Unmatched Tracks (Genuinely New)

# %%
if no_matches:
    df_no_matches = pd.DataFrame(no_matches)

    print(f"Unmatched tracks: {len(df_no_matches)}")
    print("These are genuinely new tracks not in local library:")
    print()
    display(df_no_matches[["artist", "title", "genre"]].tail(30))
else:
    print("All SoundCloud tracks matched to local tracks!")
# Out:
# Unmatched tracks: 132
# These are genuinely new tracks not in local library:
#                       artist  \
# 102               slugzmusic
# 103                Know Good
# 104               Seth David
# 105               DOMEOFDOOM
# 106                   Outset
# 107                  $LUTCHK
# 108                  Whethan
# 109                    Phrva
# 110                Jadū Dala
# 111                NIGHTMODE
# 112                CLAYBROOK
# 113                    Jiqui
# 114                  Zoey808
# 115                SIDEQUEST
# 116        Ganja White Night
# 117        Ganja White Night
# 118                  CYCLOPS
# 119  Black Tiger Sex Machine
# 120                   Flakzz
# 121                   Filthy
# 122             WODD REMIXES
# 123                    SUUNE
# 124                   Liiksu
# 125                     BEEP
# 126                   FREAKY
# 127                   IsGwan
# 128                   Mahsiv
# 129                  Łaszewo
# 130                    BAWDY
# 131                    BAWDY
#
#                                                  title        genre
# 102                       SLUGZ X PANTHER - SHELLSHOCK      Dubstep
# 103                 Paramore - Decode (Know Good Flip)         None
# 104  Zeds Dead & Flux Pavilion - WAVES (SETH DAVID ...      Dubstep
# 105                           Jack Blom - Loud N Clear   Electronic
# 106      Au5 & Tasha Baxter - Snowblind (Outset Remix)      Dubstep
# 107  $PIN 4 ME ($LUTCHK EDIT) (Spins FLO x Real 4 m...      Dubstep
# 108  Disco Lines, Tinashe - No Broke Boys (Whethan ...      Dubstep
# 109       deadmau5 & Kaskade - I Remember (Phrva Flip)      Dubstep
# 110                     Untitld - Fight Song (JADŪ015)         JADŪ
# 111                               WINK & nikko - MERCY  Dance & EDM
# 112                                      20K [FREE DL]    SKENGTYPE
# 113                                    JIQUI - PUMP UP        House
# 114             MAU P - LIKE I LIKE IT (ZOEY808 REMIX)  Dance & EDM
# 115                 NO HANDS - SIDEQUEST (CLUB WEAPON)      Dubstep
# 116              Ganja White Night x Boogie T - Burnin      Dubstep
# 117        Ganja White Night x Boogie T - Original Sin      Dubstep
# 118               BOOGIE T & CYCLOPS - NOISE COMPLAINT      Dubstep
# 119       Black Tiger Sex Machine x WODD - Brainwashed  Dance & EDM
# 120  Eminem - Superman (Flakzz Bootleg) [BIRTHDAY F...   Electronic
# 121                       Caged Within [Free Download]      Dubstep
# 122           GIMME GIMME - WODD REMIX [FREE DOWNLOAD]         None
# 123                     Apashe - UEBOK (SUUNE Bootleg)  Drum & Bass
# 124                          Weird & ODD (Liiksu Flip)      Dubstep
# 125  WODD - WEIRD & ODD [BOOPED BY BEEP] (RUNNER-UP...  Drum & Bass
# 126                           FREAKY & WODD - HOT MILK      Dubstep
# 127  FREE DL - never let u go Bootleg (Dub Pack ava...         None
# 128                 Noer the Boy - Noid (Mahsiv Remix)         None
# 129  we are the people (laszewo and distant matter....   Electronic
# 130        Hustlin' (BAWDY Flip) | Supported by Levity         Trap
# 131             MY NECK MY BACK (BAWDY Flip) (FREE DL)       100bpm

# %% [markdown]
# ### 5.4 Score Distribution Histogram

# %%
if matches:
    import matplotlib.pyplot as plt

    scores = [m["score"] for m in matches]

    plt.figure(figsize=(10, 6))
    plt.hist(scores, bins=20, edgecolor="black", alpha=0.7)
    plt.axvline(0.8, color="red", linestyle="--", label="Min threshold (0.8)")
    plt.xlabel("Similarity Score")
    plt.ylabel("Number of Tracks")
    plt.title("Distribution of Match Similarity Scores")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

# %%
# Check a few random matches to see the normalized strings
import random

if matches and len(matches) >= 3:
    print("Sample normalized comparisons:")
    print("=" * 80)

    samples = random.sample(matches, min(3, len(matches)))

    for i, match in enumerate(samples, 1):
        print(f"\nMatch {i} (score: {match['score']:.3f})")
        print(f"  SoundCloud: {match['sc_artist']} - {match['sc_title']}")
        print(f"  Local:      {match['local_artist']} - {match['local_title']}")
        print(f"  Normalized SC title:  '{normalize_string(match['sc_title'])}'")
        print(f"  Normalized LC title:  '{normalize_string(match['local_title'])}'")
        print(f"  Normalized SC artist: '{normalize_string(match['sc_artist'])}'")
        print(f"  Normalized LC artist: '{normalize_string(match['local_artist'])}'")
